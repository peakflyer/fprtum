# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
v1, der, v2, virr, ISD, ISD_minus = np.loadtxt("Draft3.txt", skiprows=1, unpack=True)

v_g = np.unique(v2)

index_2 = []

for v in v_g:
    index = np.where(v2==v)
    #plt.plot(v1[index], -ISD[index], label=v)
    #plt.plot(v1[index], -der[index], label=v)

    index_2.append(index[0][0] + np.where(der[index] == 0)[0][0])
    
plt.plot(v_g, v1[index_2], "x-", label=v)



plt.plot()

plt.legend()
plt.show()

# %%
def test_model(V_SD, a, b, R, U0=1):
    return U0 * a / ((-a * V_SD + b + R) ** 2)

vsd = np.linspace(0, 10, 100)

plt.plot(vsd, test_model(vsd, 1, 1, 10))
